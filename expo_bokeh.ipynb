# %%
import numpy as np
import pandas as pd

# %%
his = pd.read_csv("nba_user_history.csv")

# %%
his.columns
# Out:
# Index([u'GAME NAME', u'game id', u'Total number of users ',
#        u'Number of comissisoners', u'Percentage of comissoners',
#        u'Users return from last year', u'User returning rate',
#        u'Commissioner continue from last year',
#        u'commissioner continuing rate', u'Commissioner return from last year',
#        u'Commissioner returning rate', u'Player return rom last year',
#        u'Player returning rate', u'Player to commissioner',
#        u'Number of cash users', u'Avg money spent by each user'],
#       dtype='object')

# %%
from bokeh.plotting import figure, output_file, show, output_notebook
x = [1, 2, 3, 4, 5]
y = [6, 7, 2, 4, 5]
p = figure()
p.line(x,y)
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7762ff6e-4fef-4425-8d57-991cb162a82c">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="deb3a717-a7ce-4506-bfc0-d0206b8052ed"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("deb3a717-a7ce-4506-bfc0-d0206b8052ed");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("deb3a717-a7ce-4506-bfc0-d0206b8052ed");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'deb3a717-a7ce-4506-bfc0-d0206b8052ed' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"41eeccfa-277e-4863-9caf-a6bd74c99a55":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f395c09c-d16e-4e32-8898-37c9ea064f83","type":"PanTool"},{"id":"8f0e8514-d127-443f-a035-126ceef17525","type":"WheelZoomTool"},{"id":"cadf9413-c1d9-401f-89e9-5c7f64477a4b","type":"BoxZoomTool"},{"id":"1581cd15-baf0-4458-aa65-3aa79d8f08ad","type":"SaveTool"},{"id":"e5eb0071-963c-441f-9b66-bcc99128eccf","type":"ResetTool"},{"id":"99254b50-38dc-4db7-a7f5-8cfdd6a479b8","type":"HelpTool"}]},"id":"fef0d088-30a5-4b0d-a7c8-fdc6cc718f9f","type":"Toolbar"},{"attributes":{"callback":null},"id":"8421084f-ff7d-4c63-8dd7-64184d8ca59b","type":"DataRange1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"95321d3b-f6c3-4e95-90a6-27175b869b7d","type":"Line"},{"attributes":{},"id":"f300f262-3d68-4123-8978-44bfaaf06322","type":"BasicTickFormatter"},{"attributes":{},"id":"85a86f70-3d70-4d22-9921-c5532a66de5a","type":"BasicTicker"},{"attributes":{},"id":"2108e815-a114-4658-b028-4f94fd06df6f","type":"ToolEvents"},{"attributes":{},"id":"1cfb4c5c-7bf1-42fc-a421-46ee32bf4d39","type":"BasicTicker"},{"attributes":{"formatter":{"id":"19d41083-6bd6-4b01-9712-fa4ca5a9fc33","type":"BasicTickFormatter"},"plot":{"id":"21434354-b2ed-4308-a5c9-73e113686924","subtype":"Figure","type":"Plot"},"ticker":{"id":"85a86f70-3d70-4d22-9921-c5532a66de5a","type":"BasicTicker"}},"id":"3625d145-44eb-42f8-99c2-f657c82a459a","type":"LinearAxis"},{"attributes":{"callback":null},"id":"f63225d1-1a16-4f6e-b5a9-ff27341a339d","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"21434354-b2ed-4308-a5c9-73e113686924","subtype":"Figure","type":"Plot"},"ticker":{"id":"1cfb4c5c-7bf1-42fc-a421-46ee32bf4d39","type":"BasicTicker"}},"id":"7e12e536-f095-41d5-acbd-be15cbeadfb2","type":"Grid"},{"attributes":{"plot":null,"text":""},"id":"7b210032-89c7-43da-87ed-6a6a6061e1b7","type":"Title"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[1,2,3,4,5],"y":[6,7,2,4,5]}},"id":"d95b011a-4464-45dd-91a7-f03f66d6bd77","type":"ColumnDataSource"},{"attributes":{"overlay":{"id":"ef5a063b-d0a8-4c86-8b4b-1f29deb8c376","type":"BoxAnnotation"},"plot":{"id":"21434354-b2ed-4308-a5c9-73e113686924","subtype":"Figure","type":"Plot"}},"id":"cadf9413-c1d9-401f-89e9-5c7f64477a4b","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"21434354-b2ed-4308-a5c9-73e113686924","subtype":"Figure","type":"Plot"}},"id":"8f0e8514-d127-443f-a035-126ceef17525","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"21434354-b2ed-4308-a5c9-73e113686924","subtype":"Figure","type":"Plot"}},"id":"99254b50-38dc-4db7-a7f5-8cfdd6a479b8","type":"HelpTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"76b1de20-7de9-41d3-9cff-3a137f206a19","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ef5a063b-d0a8-4c86-8b4b-1f29deb8c376","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"21434354-b2ed-4308-a5c9-73e113686924","subtype":"Figure","type":"Plot"}},"id":"1581cd15-baf0-4458-aa65-3aa79d8f08ad","type":"SaveTool"},{"attributes":{"plot":{"id":"21434354-b2ed-4308-a5c9-73e113686924","subtype":"Figure","type":"Plot"}},"id":"f395c09c-d16e-4e32-8898-37c9ea064f83","type":"PanTool"},{"attributes":{"formatter":{"id":"f300f262-3d68-4123-8978-44bfaaf06322","type":"BasicTickFormatter"},"plot":{"id":"21434354-b2ed-4308-a5c9-73e113686924","subtype":"Figure","type":"Plot"},"ticker":{"id":"1cfb4c5c-7bf1-42fc-a421-46ee32bf4d39","type":"BasicTicker"}},"id":"425947dd-2d8c-474d-b920-7b984af19d5b","type":"LinearAxis"},{"attributes":{"below":[{"id":"3625d145-4 ...
